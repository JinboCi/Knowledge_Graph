# %% [markdown]
# # KG Project
#
# I am building a Fuseki Server and a Sparql Querior as this FIT Project.
#
# First of all, let's install the required packages SPARQLWrapper and rdb2rdf!

# %%
# !pip install SPARQLWrapper
# !pip install rdb2rdf
# !pip install scrapy
# Out:
# Collecting SPARQLWrapper
#   Downloading https://files.pythonhosted.org/packages/b0/1d/d7c60a451a255fca655fe37eb3f6e3b3daa7d33fc87eeec0d8631d501e76/SPARQLWrapper-1.8.4-py3-none-any.whl
# Collecting rdflib>=4.0 (from SPARQLWrapper)
#   Downloading https://files.pythonhosted.org/packages/3c/fe/630bacb652680f6d481b9febbb3e2c3869194a1a5fc3401a4a41195a2f8f/rdflib-4.2.2-py3-none-any.whl (344kB)
#      |████████████████████████████████| 348kB 12.9MB/s
# Collecting isodate (from rdflib>=4.0->SPARQLWrapper)
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 19.5MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib>=4.0->SPARQLWrapper) (2.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from isodate->rdflib>=4.0->SPARQLWrapper) (1.12.0)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-1.8.4 isodate-0.6.0 rdflib-4.2.2
# Collecting rdb2rdf
#   Downloading https://files.pythonhosted.org/packages/04/20/ec65e461969abbe4955d2bdef070872f895706af09d07f730f811ff6ee16/rdb2rdf-0.1.3.tar.gz
# Requirement already satisfied: rdflib in /usr/local/lib/python3.6/dist-packages (from rdb2rdf) (4.2.2)
# Collecting spruce-collections (from rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/32/bd/64c9598819e22800e4a87f7f6b922d1c8cfe9070ff8b9550e23a8f3f1e5a/Spruce-collections-0.2.3.tar.gz
# Collecting spruce-datetime (from rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/37/07/42aa33a8ce04bab0929e1406db1dbb318114b453fed7b4b09af10ef08fa7/Spruce-datetime-0.2.2.tar.gz
# Collecting spruce-iri (from rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/37/10/ebc0f20c310ff36bb497a9b15023561e8a03d34e164ccc43982fb215da3f/Spruce-iri-0.2.0.tar.gz
# Collecting spruce-types (from rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/64/83/fa338b569aaeaaeac36d5b146d3049abd3119fa09fba4a5e4346ec74c6f1/Spruce-types-0.1.1.tar.gz
# Requirement already satisfied: sqlalchemy>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from rdb2rdf) (1.3.6)
# Requirement already satisfied: isodate in /usr/local/lib/python3.6/dist-packages (from rdflib->rdb2rdf) (0.6.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib->rdb2rdf) (2.4.2)
# Collecting multimap (from spruce-collections->rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/4d/e3/a671749ea7122203c17d68edb99fa105b0a54c545b1fe7de5afd915038e1/MultiMap-1.0.3.tar.gz
# Collecting oset (from spruce-collections->rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/d6/b1/a49498c699a3fda5d635cc1fa222ffc686ea3b5d04b84a3166c4cab0c57b/oset-0.1.3.tar.gz
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from spruce-datetime->rdb2rdf) (2018.9)
# Collecting goosetypes (from spruce-iri->rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/61/09/91f72299ae60d84f03db969e6bd09575fa3b6ff20d39cdbc63a07d6e3ac6/GooseTypes-0.1.1.tar.gz
# Collecting spruce-exc (from spruce-types->rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/0f/9c/4029fdbb35c275c6b4c53a192b6eb9c7208ee2f0a5953c182eb8f03502d4/Spruce-exc-0.1.0.tar.gz
# Collecting spruce-lang (from spruce-types->rdb2rdf)
#   Downloading https://files.pythonhosted.org/packages/fd/74/3cb7abe0e0031f50ccbdca9369aae0569e4f007cab1d631d7c19e1f21909/Spruce-lang-0.2.0.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from isodate->rdflib->rdb2rdf) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from oset->spruce-collections->rdb2rdf) (41.0.1)
# Building wheels for collected packages: rdb2rdf, spruce-collections, spruce-datetime, spruce-iri, spruce-types, multimap, oset, goosetypes, spruce-exc, spruce-lang
#   Building wheel for rdb2rdf (setup.py) ... done
#   Created wheel for rdb2rdf: filename=rdb2rdf-0.1.3-cp36-none-any.whl size=19779 sha256=17c64d3f4c060f22f0424fceb9f3b6638bbc9fed9be971ae915999e0f5cde98a
#   Stored in directory: /root/.cache/pip/wheels/c3/2b/f1/7c9676254995cbfe394521d2e6cf41d3b959c8fc0547f66d0c
#   Building wheel for spruce-collections (setup.py) ... done
#   Created wheel for spruce-collections: filename=Spruce_collections-0.2.3-cp36-none-any.whl size=16821 sha256=d1c95c4042fc35c2184b773ffef42bb4464b1174edef7b9731270cbd336d89ab
#   Stored in directory: /root/.cache/pip/wheels/9e/32/92/c3e01a9d6afd66c7fad95a6f967543027bf68e82e491bd14fe
#   Building wheel for spruce-datetime (setup.py) ... done
#   Created wheel for spruce-datetime: filename=Spruce_datetime-0.2.2-cp36-none-any.whl size=14793 sha256=6bd6d9e65feda8bddc2c9aa47417f6d23a3612de85725f076d577cea2a94cf0c
#   Stored in directory: /root/.cache/pip/wheels/f1/7d/e9/e1838fa92057edd5ea2967e335a50444091fd4b8308aca8aac
#   Building wheel for spruce-iri (setup.py) ... done
#   Created wheel for spruce-iri: filename=Spruce_iri-0.2.0-cp36-none-any.whl size=10715 sha256=18ceb2c420ae036239195519c5effd0a881167379835581921c441b79ef893ad
#   Stored in directory: /root/.cache/pip/wheels/17/77/09/8708f7614cc831aeedaa234773dddb3c0f382dbd028043278b
#   Building wheel for spruce-types (setup.py) ... done
#   Created wheel for spruce-types: filename=Spruce_types-0.1.1-cp36-none-any.whl size=16812 sha256=c1856b591b5b630eb716dde45b2f66fdb05f629c51af8bb10b07567254d00d84
#   Stored in directory: /root/.cache/pip/wheels/6e/8f/3a/5a2c43335627edd0a26afd09dcef91389d3f950b099a5c6533
#   Building wheel for multimap (setup.py) ... done
#   Created wheel for multimap: filename=MultiMap-1.0.3-cp36-none-any.whl size=6134 sha256=3ae27984c01758788ca30a679587dab9bbd8dec37e284cb2ec8a554f8b817eed
#   Stored in directory: /root/.cache/pip/wheels/a8/0e/76/3084879a2e58cad344bbdae451dd9d87249baa8b8a890b6d92
#   Building wheel for oset (setup.py) ... done
#   Created wheel for oset: filename=oset-0.1.3-cp36-none-any.whl size=9661 sha256=2798183f2ec056d2d837793b0dbf1baa4dc007980861cef6e9ff27dd1f13cf3e
#   Stored in directory: /root/.cache/pip/wheels/4e/87/c8/3dad2dca279f64fb68af5d9908c380fee2f16488a1b1da3499
#   Building wheel for goosetypes (setup.py) ... done
#   Created wheel for goosetypes: filename=GooseTypes-0.1.1-cp36-none-any.whl size=12246 sha256=d417929dfbf16a20f6066a1429b382dbb7da7bc803fd92f9b136e70b1be5e582
#   Stored in directory: /root/.cache/pip/wheels/e8/78/a7/f9010f65ed8b17c00ca642cafde30bdf71c0bda6610945292a
#   Building wheel for spruce-exc (setup.py) ... done
#   Created wheel for spruce-exc: filename=Spruce_exc-0.1.0-cp36-none-any.whl size=8795 sha256=a66adcd9f649f7dad6b8bc7844185ffa99f4e0cda2926d2f9a56b9ae600986cc
#   Stored in directory: /root/.cache/pip/wheels/eb/de/14/ef693bf51821bc90174758c2b352ec933aec798577775b4545
#   Building wheel for spruce-lang (setup.py) ... done
#   Created wheel for spruce-lang: filename=Spruce_lang-0.2.0-cp36-none-any.whl size=8777 sha256=1b1995d4fccb29029141885ce8dc7870bc9ede08e39d39de4f4842c24cd37689
#   Stored in directory: /root/.cache/pip/wheels/0f/b5/12/856662366d56bae7fbd5917eaef31d48d76c736e246e940a7a
# Successfully built rdb2rdf spruce-collections spruce-datetime spruce-iri spruce-types multimap oset goosetypes spruce-exc spruce-lang
# Installing collected packages: multimap, oset, spruce-exc, spruce-lang, spruce-types, spruce-collections, spruce-datetime, goosetypes, spruce-iri, rdb2rdf
# Successfully installed goosetypes-0.1.1 multimap-1.0.3 oset-0.1.3 rdb2rdf-0.1.3 spruce-collections-0.2.3 spruce-datetime-0.2.2 spruce-exc-0.1.0 spruce-iri-0.2.0 spruce-lang-0.2.0 spruce-types-0.1.1
# Collecting scrapy
#   Downloading https://files.pythonhosted.org/packages/29/4b/585e8e111ffb01466c59281f34febb13ad1a95d7fb3919fd57c33fc732a5/Scrapy-1.7.3-py2.py3-none-any.whl (234kB)
#      |████████████████████████████████| 235kB 4.9MB/s
# Collecting parsel>=1.5 (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/96/69/d1d5dba5e4fecd41ffd71345863ed36a45975812c06ba77798fc15db6a64/parsel-1.5.1-py2.py3-none-any.whl
# Collecting Twisted>=13.1.0; python_version != "3.4" (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/14/49/eb654da38b15285d1f594933eefff36ce03106356197dba28ee8f5721a79/Twisted-19.7.0-cp36-cp36m-manylinux1_x86_64.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 24.4MB/s
# Collecting queuelib (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/4c/85/ae64e9145f39dd6d14f8af3fa809a270ef3729f3b90b3c0cf5aa242ab0d4/queuelib-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from scrapy) (1.12.0)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/81/43/9dcf92a77f5f0afe4f4df2407d7289eea01368a08b64bda00dd318ca62a6/w3lib-1.20.0-py2.py3-none-any.whl
# Collecting pyOpenSSL (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/01/c8/ceb170d81bd3941cbeb9940fc6cc2ef2ca4288d0ca8929ea4db5905d904d/pyOpenSSL-19.0.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 23.0MB/s
# Collecting cssselect>=0.9 (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/7b/44/25b7283e50585f0b4156960691d951b05d061abf4a714078393e51929b30/cssselect-1.0.3-py2.py3-none-any.whl
# Collecting service-identity (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/e9/7c/2195b890023e098f9618d43ebc337d83c8b38d414326685339eb024db2f6/service_identity-18.1.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from scrapy) (4.2.6)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading https://files.pythonhosted.org/packages/cd/37/39aca520918ce1935bea9c356bcbb7ed7e52ad4e31bff9b943dfc8e7115b/PyDispatcher-2.0.5.tar.gz
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from Twisted>=13.1.0; python_version != "3.4"->scrapy) (19.1.0)
# Collecting Automat>=0.3.0 (from Twisted>=13.1.0; python_version != "3.4"->scrapy)
#   Downloading https://files.pythonhosted.org/packages/a3/86/14c16bb98a5a3542ed8fed5d74fb064a902de3bdd98d6584b34553353c45/Automat-0.7.0-py2.py3-none-any.whl
# Collecting incremental>=16.10.1 (from Twisted>=13.1.0; python_version != "3.4"->scrapy)
#   Downloading https://files.pythonhosted.org/packages/f5/1d/c98a587dc06e107115cf4a58b49de20b19222c83d75335a192052af4c4b7/incremental-17.5.0-py2.py3-none-any.whl
# Collecting constantly>=15.1 (from Twisted>=13.1.0; python_version != "3.4"->scrapy)
#   Downloading https://files.pythonhosted.org/packages/b9/65/48c1909d0c0aeae6c10213340ce682db01b48ea900a7d9fce7a7910ff318/constantly-15.1.0-py2.py3-none-any.whl
# Collecting PyHamcrest>=1.9.0 (from Twisted>=13.1.0; python_version != "3.4"->scrapy)
#   Downloading https://files.pythonhosted.org/packages/9a/d5/d37fd731b7d0e91afcc84577edeccf4638b4f9b82f5ffe2f8b62e2ddc609/PyHamcrest-1.9.0-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 20.0MB/s
# Collecting hyperlink>=17.1.1 (from Twisted>=13.1.0; python_version != "3.4"->scrapy)
#   Downloading https://files.pythonhosted.org/packages/7f/91/e916ca10a2de1cb7101a9b24da546fb90ee14629e23160086cf3361c4fb8/hyperlink-19.0.0-py2.py3-none-any.whl
# Collecting zope.interface>=4.4.2 (from Twisted>=13.1.0; python_version != "3.4"->scrapy)
#   Downloading https://files.pythonhosted.org/packages/19/17/1d198a6aaa9aa4590862fe3d3a2ed7dd808050cab4eebe8a2f2f813c1376/zope.interface-4.6.0-cp36-cp36m-manylinux1_x86_64.whl (167kB)
#      |████████████████████████████████| 174kB 43.8MB/s
# Collecting cryptography>=2.3 (from pyOpenSSL->scrapy)
#   Downloading https://files.pythonhosted.org/packages/97/18/c6557f63a6abde34707196fb2cad1c6dc0dbff25a200d5044922496668a4/cryptography-2.7-cp34-abi3-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 35.2MB/s
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.6/dist-packages (from service-identity->scrapy) (0.2.5)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.6/dist-packages (from service-identity->scrapy) (0.4.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from PyHamcrest>=1.9.0->Twisted>=13.1.0; python_version != "3.4"->scrapy) (41.0.1)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.6/dist-packages (from hyperlink>=17.1.1->Twisted>=13.1.0; python_version != "3.4"->scrapy) (2.8)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.3->pyOpenSSL->scrapy) (1.12.3)
# Collecting asn1crypto>=0.21.0 (from cryptography>=2.3->pyOpenSSL->scrapy)
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 28.1MB/s
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.3->pyOpenSSL->scrapy) (2.19)
# Building wheels for collected packages: PyDispatcher
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-cp36-none-any.whl size=11517 sha256=b17c19f2a15553be4b148a9ed4f0636ca8fcf54201302370296cc4ee4b55acf2
#   Stored in directory: /root/.cache/pip/wheels/88/99/96/cfef6665f9cb1522ee6757ae5955feedf2fe25f1737f91fa7f
# Successfully built PyDispatcher
# Installing collected packages: cssselect, w3lib, parsel, Automat, incremental, constantly, PyHamcrest, hyperlink, zope.interface, Twisted, queuelib, asn1crypto, cryptography, pyOpenSSL, service-identity, PyDispatcher, scrapy
# Successfully installed Automat-0.7.0 PyDispatcher-2.0.5 PyHamcrest-1.9.0 Twisted-19.7.0 asn1crypto-0.24.0 constantly-15.1.0 cryptography-2.7 cssselect-1.0.3 hyperlink-19.0.0 incremental-17.5.0 parsel-1.5.1 pyOpenSSL-19.0.0 queuelib-1.5.0 scrapy-1.7.3 service-identity-18.1.0 w3lib-1.20.0 zope.interface-4.6.0

# %%
import scrapy
import re

from scrapy.crawler import CrawlerProcess
import csv
import logging

import os
import sys
import time
import random
import datetime

from SPARQLWrapper import SPARQLWrapper, JSON, XML

import csv
import rdflib
from rdflib import URIRef, BNode, Literal
from rdflib import Namespace
from rdflib.namespace import RDF, FOAF
from rdflib import Graph, Literal

# %% [markdown]
# ## Collecting data
#
# At beginning, we are going to collect our data, we will use the build-in module *scrapy* to crawl the information on the website and convert it into SQL database formats.

# %% [markdown]
# ### A simple verison
#
# In this part, we will only consider three kinds of information of the Nobel Prize Winners:
# - country
# - name
# - link_text

# %%
# nwinners_list_spider.py

# A. Define the data to be scraped
class NWinnerItem(scrapy.Item):
  country = scrapy.Field()
  name = scrapy.Field()
  link_text = scrapy.Field()

  
# B Create a named spider
class NWinnerSpiderSimp(scrapy.Spider):
  """ Scrapes the country and link-text of the Nobel-winners. """
  name = 'nwinners_list'
  allowed_domains = ['en.wikipedia.org']
  start_urls = ["https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country"]

  
  # C A parse method to deal with the HTTP response
  def parse(self, response):
    h3s = response.xpath('//h3')
    items = []
    for h3 in h3s:
      country = h3.xpath('span[@class="mw-headline"]/text()')\
      .extract()
      if country:
        winners = h3.xpath('following-sibling::ol[1]')
        for w in winners.xpath('li'):
          text = w.xpath('descendant-or-self::text()')\
          .extract()
          items.append(NWinnerItem(
            country=country[0], name=text[0],
            link_text = ' '.join(text)
            ))
    return items

# %% [markdown]
# Sounds good? Haha, we would not run this version, since we will have a more comprehensive one, which could deliver more information

# %% [markdown]
# ### A comprehensive version
#
# Besides *country*, *name*, *link_text* that we have previously considered, in this part, we will fetch more information about Nobel Prize Winners, including:
#  - year
#  - category
#  - nationality
#  - gender
#  - born_in
#  - date_of_birth
#  - date_of_death
#  - place_of_birth
#  - place_of_death

# %%
BASE_URL = 'http://en.wikipedia.org'
class NWinnerItem(scrapy.Item):
  name = scrapy.Field()
  link = scrapy.Field()
  year = scrapy.Field()
  category = scrapy.Field()
  nationality = scrapy.Field()
  gender = scrapy.Field()
  born_in = scrapy.Field()
  date_of_birth = scrapy.Field()
  date_of_death = scrapy.Field()
  place_of_birth = scrapy.Field()
  place_of_death = scrapy.Field()
  text = scrapy.Field()
  
# B Create a named spider
class NWinnerSpiderComph(scrapy.Spider):
  """ Scrapes the country and link-text of the Nobel-winners. """
  name = 'nwinners_list'
  allowed_domains = ['en.wikipedia.org']
  start_urls = ["https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country"]

  
  # C A parse method to deal with the HTTP response
  def parse(self, response):
    h3s = response.xpath('//h3')
    items = []
    for h3 in h3s:
      country = h3.xpath('span[@class="mw-headline"]/text()')\
                .extract()
      if country:
        winners = h3.xpath('following-sibling::ol[1]')
        for w in winners.xpath('li'):
          wdata = self.process_winner_li(w, country[0])
          request = scrapy.Request(
            wdata['link'],
            callback=self.parse_bio,
            dont_filter=True)
          request.meta['item'] = NWinnerItem(**wdata)
          yield request
    return items
  def process_winner_li(self, w, country=None):
    """
    Process a winner's <li> tag, adding country of birth or
    nationality, as applicable.
    """
    wdata = {}
    wdata['link'] = BASE_URL + w.xpath('a/@href').extract()[0]
    text = ' '.join(w.xpath('descendant-or-self::text()').extract())
    # get comma-delineated name and strip trailing white-space
    wdata['name'] = text.split(',')[0].strip()
    # see if there are four adjecent integers in the string text
    year = re.findall('\d{4}', text)
    if year:
      wdata['year'] = int(year[0])
    else:
      wdata['year'] = 0
      print('Oops, no year in ', text)
    category = re.findall('Physics|Chemistry|Physiology or Medicine|Literature|Peace|Economics',text)
    if category:
      wdata['category'] = category[0]
    else:
      wdata['category'] = ''
      print('Oops, no category in ', text)
    if country:
      # the interesting label that represent his nationality or motherland
      if text.find('*') != -1:
        wdata['nationality'] = ''
        wdata['born_in'] = country
      else:
        wdata['nationality'] = country
        wdata['born_in'] = ''
    # store a copy of the link's text-string for any manual corrections
    wdata['text'] = text
    return wdata
  
  def parse_bio(self, response):
    item = response.meta['item']
    href = response.xpath("//li[@id='t-wikibase']/a/@href").extract()
    if href:
      request = scrapy.Request(href[0],\
                  callback=self.parse_wikidata,\
                              dont_filter=True)
      request.meta['item'] = item
      yield request
  def parse_wikidata(self, response):
    item = response.meta['item']
    property_codes = [
      {'name':'date_of_birth', 'code':'P569'},
      {'name':'date_of_death', 'code':'P570'},
      {'name':'place_of_birth', 'code':'P19', 'link':True},
      {'name':'place_of_death', 'code':'P20', 'link':True},
      {'name':'gender', 'code':'P21', 'link':True}
    ]    
    p_template = '//*[@id="%(code)s"]/div[2]/div[1]/div/div[2]/div[2]/div[1]'
    for prop in property_codes:
      extra_html = ''
      if prop.get('link'): # property string in <a> tag
        extra_html = '/a'
      sel = response.xpath(p_template%prop + extra_html + '/text()')
      if sel:
        item[prop['name']] = sel[0].extract()
    yield item

# %% [markdown]
# ### Storing to CSV
# Looks good? But we may want to write the results to csv files or directly store it to our sql database. How could we achieve this?
#
# Hmm...
#
# We may first store the data to csv, and then upload the csv file to our sql server!

# %%
import pdb
BASE_URL = 'http://en.wikipedia.org'
class NWinnerItem(scrapy.Item):
  name = scrapy.Field()
  link = scrapy.Field()
  year = scrapy.Field()
  category = scrapy.Field()
  nationality = scrapy.Field()
  gender = scrapy.Field()
  born_in = scrapy.Field()
  date_of_birth = scrapy.Field()
  date_of_death = scrapy.Field()
  place_of_birth = scrapy.Field()
  place_of_death = scrapy.Field()
  text = scrapy.Field()
  
# B Create a named spider
class NWinnerSpiderToCsv(scrapy.Spider):
  """ Scrapes the country and link-text of the Nobel-winners. """
  name = 'nwinners_list'
  allowed_domains = ['en.wikipedia.org']
  start_urls = ["https://en.wikipedia.org/wiki/List_of_Nobel_laureates_by_country"]
  items = []
  output = name+".csv" 
  custom_settings = {
      'LOG_LEVEL': 'INFO',
      'FEED_FORMAT':'csv',
      'FEED_URI': 'nwinners_list.csv'
    }
  '''
  def __init__(self):
    if os.path.isfile(self.output):
      os.remove(self.output)
    open(self.output, "w").close()
  '''

  
  # C A parse method to deal with the HTTP response
  def parse(self, response):
    h3s = response.xpath('//h3')
    for h3 in h3s:
      country = h3.xpath('span[@class="mw-headline"]/text()')\
                .extract()
      if country:
        winners = h3.xpath('following-sibling::ol[1]')
        for w in winners.xpath('li'):
          wdata = self.process_winner_li(w, country[0])
          #pdb.set_trace()
          request = scrapy.Request(
            wdata['link'],
            callback=self.parse_bio,
            dont_filter=True)
          #pdb.set_trace()
          request.meta['item'] = NWinnerItem(**wdata)
          yield request
          #pdb.set_trace()
    #pdb.set_trace()
    return self.items
  
      
  def process_winner_li(self, w, country=None):
    """
    Process a winner's <li> tag, adding country of birth or
    nationality, as applicable.
    """
    wdata = {}
    wdata['link'] = BASE_URL + w.xpath('a/@href').extract()[0]
    text = ' '.join(w.xpath('descendant-or-self::text()').extract())
    # get comma-delineated name and strip trailing white-space
    wdata['name'] = text.split(',')[0].strip()
    # see if there are four adjecent integers in the string text
    year = re.findall('\d{4}', text)
    if year:
      wdata['year'] = int(year[0])
    else:
      wdata['year'] = 0
      print('Oops, no year in ', text)
    category = re.findall('Physics|Chemistry|Physiology or Medicine|Literature|Peace|Economics',text)
    if category:
      wdata['category'] = category[0]
    else:
      wdata['category'] = ''
      print('Oops, no category in ', text)
    if country:
      # the interesting label that represent his nationality or motherland
      if text.find('*') != -1:
        wdata['nationality'] = ''
        wdata['born_in'] = country
      else:
        wdata['nationality'] = country
        wdata['born_in'] = ''
    # store a copy of the link's text-string for any manual corrections
    wdata['text'] = text
    #pdb.set_trace()
    return wdata
  
  def parse_bio(self, response):
    #pdb.set_trace()
    item = response.meta['item']
    href = response.xpath("//li[@id='t-wikibase']/a/@href").extract()
    if href:
      request = scrapy.Request(href[0],\
                  callback=self.parse_wikidata,\
                              dont_filter=True)
      request.meta['item'] = item
      return request
  def parse_wikidata(self, response):
    #pdb.set_trace()
    item = response.meta['item']
    property_codes = [
      {'name':'date_of_birth', 'code':'P569'},
      {'name':'date_of_death', 'code':'P570'},
      {'name':'place_of_birth', 'code':'P19', 'link':True},
      {'name':'place_of_death', 'code':'P20', 'link':True},
      {'name':'gender', 'code':'P21', 'link':True}
    ]
    # this template should be obtained by carefully examining the webpage's elements
    p_template = '//*[@id="%(code)s"]/div[2]/div/div/div[2]/div[1]/div/div[2]/div[2]/div[1]'
    for prop in property_codes:
      extra_html = ''
      if prop.get('link'): # property string in <a> tag
        extra_html = '/a'
      
      sel = response.xpath(p_template%prop + extra_html + '/text()')
      #pdb.set_trace()
      if sel:
        item[prop['name']] = sel[0].extract()
      else:
        item[prop['name']] = ""
    self.items.append(NWinnerItem(name=item["name"], link=item["link"], 
                                   year=item["year"], category=item["category"],
                                  nationality=item["nationality"], gender=item["gender"],
                                  born_in=item["born_in"], date_of_birth=item["date_of_birth"],
                                  date_of_death=item["date_of_death"],
                                  place_of_birth=item["place_of_birth"],
                                  place_of_death=item["place_of_death"],
                                  text=item["text"]))
    return item

# %% [markdown]
# Now, let's try to see how this comprehensive version works:

# %%
process = CrawlerProcess()
process.crawl(NWinnerSpiderToCsv)
process.start()
# Out:
# 2019-08-07 09:34:36 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: scrapybot)
# 2019-08-07 09:34:36 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 19.7.0, Python 3.6.8 (default, Jan 14 2019, 11:02:34) - [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic
# 2019-08-07 09:34:36 [scrapy.crawler] INFO: Overridden settings: {'FEED_URI': 'stdout', 'LOG_LEVEL': 'INFO'}
# 2019-08-07 09:34:36 [scrapy.extensions.telnet] INFO: Telnet Password: 03296ed8915f226f
# 2019-08-07 09:34:36 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2019-08-07 09:34:36 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-08-07 09:34:36 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-08-07 09:34:36 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-08-07 09:34:36 [scrapy.core.engine] INFO: Spider opened
# 2019-08-07 09:34:36 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-08-07 09:34:36 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# Oops, no category in  Róbert Bárány ,  born in Austria-Hungary , Medicine, 1914
# Oops, no category in  Andrew Schally *,  born in Wilno, Second Polish Republic (now Vilnius, Lithuania) , Medicine, 1977
# 2019-08-07 09:35:36 [scrapy.extensions.logstats] INFO: Crawled 1313 pages (at 1313 pages/min), scraped 644 items (at 644 items/min)
# 2019-08-07 09:36:21 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-08-07 09:36:21 [scrapy.extensions.feedexport] INFO: Stored jsonlines feed (1123 items) in: stdout
# 2019-08-07 09:36:21 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1537336,
#  'downloader/request_count': 4493,
#  'downloader/request_method_count/GET': 4493,
#  'downloader/response_bytes': 83742845,
#  'downloader/response_count': 4493,
#  'downloader/response_status_count/200': 2247,
#  'downloader/response_status_count/301': 2246,
#  'elapsed_time_seconds': 104.73797,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 8, 7, 9, 36, 21, 444291),
#  'item_scraped_count': 1123,
#  'log_count/INFO': 12,
#  'memusage/max': 452796416,
#  'memusage/startup': 176656384,
#  'request_depth_max': 2,
#  'response_received_count': 2247,
#  'scheduler/dequeued': 4493,
#  'scheduler/dequeued/memory': 4493,
#  'scheduler/enqueued': 4493,
#  'scheduler/enqueued/memory': 4493,
#  'start_time': datetime.datetime(2019, 8, 7, 9, 34, 36, 706321)}
# 2019-08-07 09:36:21 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Building Graphs
#
# The code in this part is to generate RDF graphs from datasets using the method called "RDB2RDF".

# %% [markdown]
# ### Formatted datasets
#
# In this part, we would build our RDF graphs from formatted datasets (i.e. CSV files). We would achieve it by applying the libraries *rdflib* and *csv*.

# %%
def R2RDF(filepath, output):
  first_Row = True
  graph = Graph()
  if os.path.isfile(filepath):
    with open(filepath, encoding="utf-8") as csvfile:
      readCSV = csv.reader(csvfile,delimiter=',')
      wiki_prefix = Namespace('https://en.wikipedia.org/wiki/')
      for row in readCSV:
        #print(row)
        if first_Row == True:
          first_Row = False
          continue
        born_in = Literal(row[0])
        category = Literal(row[1])
        date_of_birth = Literal(row[2])
        date_of_death = Literal(row[3])
        gender = Literal(row[4])
        link = Literal(row[5])
        name = Literal(row[6])
        nationality = Literal(row[7])
        place_of_birth = Literal(row[8])
        place_of_death = Literal(row[9])
        text = Literal(row[10])
        year = Literal(row[11])
        current_node = URIRef(link)
        graph.add((current_node, RDF.type, FOAF.Person))
        graph.add((current_node, FOAF.name, name))
        graph.add((current_node, wiki_prefix.homeland, born_in))
        #if born_in != "":
        #graph.add((born_in, RDF.type, wiki_prefix.country))
        graph.add((current_node, wiki_prefix.Course_education, category))
        graph.add((current_node, wiki_prefix.date_of_birth,date_of_birth))
        #graph.add((date_of_birth, RDF.type, FOAF.Date))
        #if date_of_death != "":
          #graph.add((date_of_death, RDF.type, FOAF.Date))
        graph.add((current_node, wiki_prefix.date_of_death, date_of_death))
        #if gender != "":
        graph.add((current_node, FOAF.gender, gender))
        graph.add((current_node, FOAF.accountServiceHomepage, link))
        graph.add((current_node, wiki_prefix.nationality, nationality))
        #graph.add((nationality, RDF.type, wiki_prefix.country))
        #if place_of_birth != "":
        graph.add((current_node, wiki_prefix.place_of_birth, place_of_birth))
        #graph.add((place_of_birth, RDF.type, wiki_prefix.city))
        #if place_of_death != "":
        graph.add((current_node, wiki_prefix.place_of_death, place_of_death))
        #graph.add((place_of_death, RDF.type, wiki_prefix.city))
        graph.add((current_node, FOAF.depiction, text))
        graph.add((current_node, wiki_prefix.year, year))
    if os.path.isfile(output):
        os.remove(output)
    graph.serialize(destination=output, format='pretty-xml')

# %% [markdown]
# Now let's look how it works:

# %%
R2RDF('nwinners_list.csv', 'nwinners_list.ttl')

# %%
R2RDF('nwinners_list.csv', 'nwinners_list.xml')

# %% [markdown]
# ## Sparql Querior
#
# We are writing a class that is able to achieve basic implementations of the SPQRQL queries for an RDF database.

# %% [markdown]
# ### Query_with_SPARQLWrapper
# The following functions are to be considered:
#
# - Function *init*
# - Function *Querying_database*
#
# The Fit_project and its member functions would take the inputs:
#
# - Url: the path of the RDF graph
#
# - Enum: the indication that where the *Input_stirng* is the path of an input file or the sparql request
#
# - Return_format: JSON or XML

# %%
import pdb
class Query_with_SPARQLWrapper:
    File_or_Query = {
        "File",
        "Query",
    }
    Return_format = {
        "JSON": JSON,
        "XML": XML,
    }
    File_path = ""
    Query_string = ""
    Url = ""
    Sparql = SPARQLWrapper("")
    def __init__(self, Url):
        self.Sparql = SPARQLWrapper(Url)
    def Querying_database(self, Enum, Input_string, Return_format):
        if Enum == "File":
            self.File_path = Input_string
            if not os.path.isfile(self.File_path):
                raise TypeError(self.File_path + " does not exist")
            self.Query_string = open(self.File_path).read().close()
        else:
            self.Query_string = Input_string
        self.Sparql.setQuery(self.Query_string)
        #pdb.set_trace()
        if Return_format == "JSON":
            self.Sparql.setReturnFormat(JSON)
        else:
            self.Sparql.setReturnFormat(XML)
        results = self.Sparql.query().convert()
        return results

# %% [markdown]
# Now let's see how it works:

# %%
Fp = Fit_project("https://raw.githubusercontent.com/JinboCi/Sparql_tutorials/master/nwinner_list.xml")
print(Fp.Querying_database("Query", 
                           """SELECT ?subject ?predicate 
WHERE {
  # ?subject ?predicate "Chicago"
}
LIMIT 25""", 
                           "JSON").decode('utf-8'))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns:ns1="http://xmlns.com/foaf/0.1/"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#   xmlns:ns2="https://en.wikipedia.org/wiki/"
# >
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Isaac_Bashevis_Singer">
#     <ns1:name>Isaac Bashevis Singer</ns1:name>
#     <ns1:name>Isaac Bashevis Singer *</ns1:name>
#     <ns2:place_of_birth>Leoncin</ns2:place_of_birth>
#     <ns2:nationality></ns2:nationality>
#     <ns2:date_of_death>24 July 1991</ns2:date_of_death>
#     <ns1:depiction>Isaac Bashevis Singer ,  born in then Russian Empire, now Poland , Literature, 1978</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>Miami</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Isaac_Bashevis_Singer</ns1:accountServiceHomepage>
#     <ns2:homeland>Poland</ns2:homeland>
#     <ns2:year>1978</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>21 November 1902</ns2:date_of_birth>
#     <ns1:depiction>Isaac Bashevis Singer *,  born in Congress Poland (Russian Empire) , Literature, 1978</ns1:depiction>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:nationality>United States</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Albert_Szent-Gy%C3%B6rgyi">
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Albert_Szent-Gy%C3%B6rgyi</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns2:nationality>Hungary</ns2:nationality>
#     <ns2:year>1937</ns2:year>
#     <ns1:name>Albert Szent-Györgyi</ns1:name>
#     <ns2:place_of_birth>Budapest</ns2:place_of_birth>
#     <ns1:depiction>Albert Szent-Györgyi , Physiology or Medicine, 1937</ns1:depiction>
#     <ns2:date_of_birth>16 September 1893</ns2:date_of_birth>
#     <ns2:place_of_death>Woods Hole</ns2:place_of_death>
#     <ns2:date_of_death>22 October 1986</ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Charles_B._Huggins">
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Charles_B._Huggins</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>Chicago</ns2:place_of_death>
#     <ns1:depiction>Charles B. Huggins ,  born in Canada , Physiology or Medicine, 1966</ns1:depiction>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:name>Charles B. Huggins</ns1:name>
#     <ns2:date_of_birth>22 September 1901</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Halifax</ns2:place_of_birth>
#     <ns2:year>1966</ns2:year>
#     <ns2:date_of_death>12 January 1997</ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Samuel_C._C._Ting">
#     <ns2:date_of_birth>27 January 1936</ns2:date_of_birth>
#     <ns2:nationality>Taiwan (China, Republic of)</ns2:nationality>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Samuel_C._C._Ting</ns1:accountServiceHomepage>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:place_of_birth>Ann Arbor</ns2:place_of_birth>
#     <ns2:year>1976</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Samuel C. C. Ting</ns1:name>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>Samuel C. C. Ting , Physics, 1976</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Imre_Kert%C3%A9sz">
#     <ns2:year>2002</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Imre Kertész , Literature, 2002</ns1:depiction>
#     <ns2:date_of_death>31 March 2016</ns2:date_of_death>
#     <ns2:place_of_death>Budapest</ns2:place_of_death>
#     <ns2:nationality>Hungary</ns2:nationality>
#     <ns1:name>Imre Kertész</ns1:name>
#     <ns2:date_of_birth>9 November 1929</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Budapest</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Imre_Kert%C3%A9sz</ns1:accountServiceHomepage>
#     <ns2:Course_education>Literature</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Patrick_Modiano">
#     <ns2:place_of_birth>Boulogne-Billancourt</ns2:place_of_birth>
#     <ns1:name>Patrick Modiano</ns1:name>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:date_of_birth>30 July 1945</ns2:date_of_birth>
#     <ns2:year>2014</ns2:year>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>Patrick Modiano , Literature, 2014</ns1:depiction>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Patrick_Modiano</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Toshihide_Maskawa">
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>2008</ns2:year>
#     <ns2:place_of_birth>Nagoya</ns2:place_of_birth>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns2:date_of_birth>7 February 1940</ns2:date_of_birth>
#     <ns2:nationality>Japan</ns2:nationality>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>Toshihide Maskawa , Physics, 2008</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Toshihide_Maskawa</ns1:accountServiceHomepage>
#     <ns1:name>Toshihide Maskawa</ns1:name>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Reinhard_Selten">
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>Germany</ns2:nationality>
#     <ns1:name>Reinhard Selten</ns1:name>
#     <ns2:place_of_death>Poznań</ns2:place_of_death>
#     <ns1:depiction>Reinhard Selten , Economics, 1994</ns1:depiction>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Reinhard_Selten</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>1994</ns2:year>
#     <ns2:date_of_death>23 August 2016</ns2:date_of_death>
#     <ns2:place_of_birth>Wrocław</ns2:place_of_birth>
#     <ns2:date_of_birth>5 October 1930</ns2:date_of_birth>
#     <ns2:Course_education>Economics</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Joseph_Brodsky">
#     <ns1:name>Joseph Brodsky</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>1987</ns2:year>
#     <ns1:depiction>Joseph Brodsky , born in Russia, Literature, 1987</ns1:depiction>
#     <ns2:date_of_death>28 January 1996</ns2:date_of_death>
#     <ns2:place_of_death>Brooklyn</ns2:place_of_death>
#     <ns2:nationality>Russia and Soviet Union</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns1:depiction>Joseph Brodsky ,  born in Russia , Literature, 1987</ns1:depiction>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:date_of_birth>24 May 1940</ns2:date_of_birth>
#     <ns2:place_of_birth>Saint Petersburg</ns2:place_of_birth>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Joseph_Brodsky</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Jean-Pierre_Sauvage">
#     <ns2:place_of_birth>Paris</ns2:place_of_birth>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:date_of_birth>21 October 1944</ns2:date_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Jean-Pierre_Sauvage</ns1:accountServiceHomepage>
#     <ns1:name>Jean-Pierre Sauvage</ns1:name>
#     <ns1:depiction>Jean-Pierre Sauvage , Chemistry, 2016</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:year>2016</ns2:year>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Jack_Steinberger">
#     <ns2:place_of_birth>Bad Kissingen</ns2:place_of_birth>
#     <ns1:depiction>Jack Steinberger *, Physics, 1988</ns1:depiction>
#     <ns2:homeland>Germany</ns2:homeland>
#     <ns1:depiction>Jack Steinberger ,  born in Germany , Physics, 1988</ns1:depiction>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:name>Jack Steinberger *</ns1:name>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Jack_Steinberger</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_birth>25 May 1921</ns2:date_of_birth>
#     <ns1:name>Jack Steinberger</ns1:name>
#     <ns2:nationality></ns2:nationality>
#     <ns2:year>1988</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death></ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Georges_J.F._K%C3%B6hler">
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Georges_J.F._K%C3%B6hler</ns1:accountServiceHomepage>
#     <ns2:place_of_death>Freiburg im Breisgau</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death>1 March 1995</ns2:date_of_death>
#     <ns2:homeland>Germany</ns2:homeland>
#     <ns1:name>Georges J.F. Köhler *</ns1:name>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:date_of_birth>17 April 1946</ns2:date_of_birth>
#     <ns2:nationality></ns2:nationality>
#     <ns2:year>1984</ns2:year>
#     <ns2:place_of_birth>Munich</ns2:place_of_birth>
#     <ns1:depiction>Georges J.F. Köhler *, Physiology or Medicine, 1984</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Derek_Walcott">
#     <ns2:place_of_death>Gros Islet Quarter</ns2:place_of_death>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:date_of_death>17 March 2017</ns2:date_of_death>
#     <ns2:place_of_birth>Castries</ns2:place_of_birth>
#     <ns1:depiction>Derek Walcott , Literature, 1992</ns1:depiction>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Derek_Walcott</ns1:accountServiceHomepage>
#     <ns2:year>1992</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns1:name>Derek Walcott</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:nationality>Saint Lucia</ns2:nationality>
#     <ns2:date_of_birth>23 January 1930</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/John_Bennett_Fenn">
#     <ns2:date_of_birth>15 June 1917</ns2:date_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/John_Bennett_Fenn</ns1:accountServiceHomepage>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:year>2002</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>New York City</ns2:place_of_birth>
#     <ns1:name>John Bennett Fenn</ns1:name>
#     <ns2:place_of_death>Richmond</ns2:place_of_death>
#     <ns2:date_of_death>10 December 2010</ns2:date_of_death>
#     <ns1:depiction>John Bennett Fenn , Chemistry, 2002</ns1:depiction>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/David_Trimble">
#     <ns2:nationality>Ireland</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>David Trimble , Peace, 1998</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>1998</ns2:year>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:place_of_birth>Bangor</ns2:place_of_birth>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:name>David Trimble</ns1:name>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/David_Trimble</ns1:accountServiceHomepage>
#     <ns2:date_of_birth>15 October 1944</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Bengt_I._Samuelsson">
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:nationality>Sweden</ns2:nationality>
#     <ns2:place_of_birth>Halmstad</ns2:place_of_birth>
#     <ns1:depiction>Bengt I. Samuelsson , Physiology or Medicine, 1982</ns1:depiction>
#     <ns2:year>1982</ns2:year>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Bengt_I._Samuelsson</ns1:accountServiceHomepage>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:date_of_birth>21 May 1934</ns2:date_of_birth>
#     <ns1:name>Bengt I. Samuelsson</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/John_Forbes_Nash">
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns1:depiction>John Forbes Nash , Economics, 1994</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/John_Forbes_Nash</ns1:accountServiceHomepage>
#     <ns1:name>John Forbes Nash</ns1:name>
#     <ns2:place_of_birth>Bluefield</ns2:place_of_birth>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:place_of_death>Monroe Township</ns2:place_of_death>
#     <ns2:date_of_birth>13 June 1928</ns2:date_of_birth>
#     <ns2:date_of_death>23 May 2015</ns2:date_of_death>
#     <ns2:year>1994</ns2:year>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Joseph_Murray">
#     <ns2:place_of_death>Boston</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Joseph_Murray</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Milford</ns2:place_of_birth>
#     <ns2:year>1990</ns2:year>
#     <ns2:date_of_death>26 November 2012</ns2:date_of_death>
#     <ns2:date_of_birth>1 April 1919</ns2:date_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Joseph E. Murray</ns1:name>
#     <ns1:depiction>Joseph E. Murray , Physiology or Medicine, 1990</ns1:depiction>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Robert_Aumann">
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>Robert Aumann *,  as an  Israeli  citizen , Economics, 2005</ns1:depiction>
#     <ns2:homeland>United States</ns2:homeland>
#     <ns2:year>2005</ns2:year>
#     <ns1:name>Robert Aumann *</ns1:name>
#     <ns2:date_of_birth>8 June 1930</ns2:date_of_birth>
#     <ns1:name>Robert Aumann</ns1:name>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:nationality>Israel</ns2:nationality>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns2:nationality></ns2:nationality>
#     <ns2:place_of_birth>Frankfurt am Main</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Robert_Aumann</ns1:accountServiceHomepage>
#     <ns1:depiction>Robert Aumann ,  born in Germany ,  moved to Israel from America , Economics, 2005</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Irwin_Rose">
#     <ns2:place_of_birth>Brooklyn</ns2:place_of_birth>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#     <ns2:year>2004</ns2:year>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:date_of_death>2 June 2015</ns2:date_of_death>
#     <ns2:homeland></ns2:homeland>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>Deerfield</ns2:place_of_death>
#     <ns1:depiction>Irwin Rose , Chemistry, 2004</ns1:depiction>
#     <ns1:name>Irwin Rose</ns1:name>
#     <ns2:date_of_birth>16 July 1926</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Irwin_Rose</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Christiaan_Eijkman">
#     <ns1:name>Christiaan Eijkman</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:place_of_death>Utrecht</ns2:place_of_death>
#     <ns2:date_of_birth>11 August 1858</ns2:date_of_birth>
#     <ns1:depiction>Christiaan Eijkman , Physiology or Medicine, 1929</ns1:depiction>
#     <ns2:year>1929</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns2:nationality>Netherlands</ns2:nationality>
#     <ns2:date_of_death>5 November 1930</ns2:date_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Christiaan_Eijkman</ns1:accountServiceHomepage>
#     <ns2:place_of_birth>Nijkerk</ns2:place_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Clifford_Shull">
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death>31 March 2001</ns2:date_of_death>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns1:name>Clifford G. Shull</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:year>1994</ns2:year>
#     <ns2:place_of_birth>Pittsburgh</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Clifford_Shull</ns1:accountServiceHomepage>
#     <ns2:date_of_birth>23 September 1915</ns2:date_of_birth>
#     <ns1:depiction>Clifford G. Shull , Physics, 1994</ns1:depiction>
#     <ns2:place_of_death>Medford</ns2:place_of_death>
#     <ns2:nationality>United States</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/James_P._Allison">
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/James_P._Allison</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns1:name>James Allison</ns1:name>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>James Allison , Physiology or Medicine, 2018</ns1:depiction>
#     <ns2:place_of_birth>Alice</ns2:place_of_birth>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:year>2018</ns2:year>
#     <ns2:date_of_birth>7 August 1948</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Werner_Karl_Heisenberg">
#     <ns2:date_of_death>1 February 1976</ns2:date_of_death>
#     <ns2:date_of_birth>5 December 1901</ns2:date_of_birth>
#     <ns2:place_of_birth>Würzburg</ns2:place_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>Germany</ns2:nationality>
#     <ns2:year>1932</ns2:year>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns1:gender>male</ns1:gender>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Werner_Karl_Heisenberg</ns1:accountServiceHomepage>
#     <ns1:name>Werner Karl Heisenberg</ns1:name>
#     <ns2:place_of_death>Munich</ns2:place_of_death>
#     <ns1:depiction>Werner Karl Heisenberg , Physics, 1932</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Walther_Bothe">
#     <ns2:year>1954</ns2:year>
#     <ns1:depiction>Walther Bothe , Physics, 1954</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>Germany</ns2:nationality>
#     <ns2:date_of_death>8 February 1957</ns2:date_of_death>
#     <ns2:date_of_birth>8 January 1891</ns2:date_of_birth>
#     <ns2:place_of_birth>Oranienburg</ns2:place_of_birth>
#     <ns1:name>Walther Bothe</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>Heidelberg</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Walther_Bothe</ns1:accountServiceHomepage>
#     <ns2:Course_education>Physics</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Denis_Mukwege">
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:nationality>Congo, Democratic Republic</ns2:nationality>
#     <ns2:place_of_birth>Bukavu</ns2:place_of_birth>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Denis_Mukwege</ns1:accountServiceHomepage>
#     <ns2:year>2018</ns2:year>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>Denis Mukwege , Peace, 2018</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>1 March 1955</ns2:date_of_birth>
#     <ns1:name>Denis Mukwege</ns1:name>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/James_M._Buchanan">
#     <ns2:date_of_birth>3 October 1919</ns2:date_of_birth>
#     <ns2:place_of_birth>Murfreesboro</ns2:place_of_birth>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death>Blacksburg</ns2:place_of_death>
#     <ns1:name>James M. Buchanan</ns1:name>
#     <ns1:depiction>James M. Buchanan , Economics, 1986</ns1:depiction>
#     <ns2:year>1986</ns2:year>
#     <ns2:date_of_death>9 January 2013</ns2:date_of_death>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/James_M._Buchanan</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Passy">
#     <ns1:name>Frédéric Passy</ns1:name>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Fr%C3%A9d%C3%A9ric_Passy</ns1:accountServiceHomepage>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:date_of_death>12 June 1912</ns2:date_of_death>
#     <ns2:place_of_birth>Paris</ns2:place_of_birth>
#     <ns2:year>1901</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Frédéric Passy , Peace, 1901</ns1:depiction>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:date_of_birth>20 May 1822</ns2:date_of_birth>
#     <ns2:place_of_death>Neuilly-sur-Seine</ns2:place_of_death>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Andrew_Schally">
#     <ns2:place_of_birth>Vilnius</ns2:place_of_birth>
#     <ns2:nationality></ns2:nationality>
#     <ns2:date_of_birth>30 November 1926</ns2:date_of_birth>
#     <ns1:name>Andrew Schally</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education></ns2:Course_education>
#     <ns1:name>Andrew Schally *</ns1:name>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>Andrew Schally ,  born in then Poland, now Lithuania , Physiology or Medicine, 1977</ns1:depiction>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:homeland>Poland</ns2:homeland>
#     <ns2:year>1977</ns2:year>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:depiction>Andrew Schally *,  born in Wilno, Second Polish Republic (now Vilnius, Lithuania) , Medicine, 1977</ns1:depiction>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Andrew_Schally</ns1:accountServiceHomepage>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Carlo_Rubbia">
#     <ns2:year>1984</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Carlo_Rubbia</ns1:accountServiceHomepage>
#     <ns1:name>Carlo Rubbia</ns1:name>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>Carlo Rubbia , Physics, 1984</ns1:depiction>
#     <ns2:date_of_birth>31 March 1934</ns2:date_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_birth>Gorizia</ns2:place_of_birth>
#     <ns2:nationality>Italy</ns2:nationality>
#     <ns2:Course_education>Physics</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Rudolph_A._Marcus">
#     <ns2:place_of_birth>Montreal</ns2:place_of_birth>
#     <ns2:nationality></ns2:nationality>
#     <ns1:name>Rudolph A. Marcus</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>Rudolph A. Marcus ,  born in Canada , Chemistry, 1992</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>21 July 1923</ns2:date_of_birth>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:name>Rudolph A. Marcus *</ns1:name>
#     <ns1:depiction>Rudolph A. Marcus *, Chemistry, 1992</ns1:depiction>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Rudolph_A._Marcus</ns1:accountServiceHomepage>
#     <ns2:homeland>Canada</ns2:homeland>
#     <ns2:year>1992</ns2:year>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/W._B._Yeats">
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/W._B._Yeats</ns1:accountServiceHomepage>
#     <ns1:name>W. B. Yeats</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>1923</ns2:year>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:date_of_death>28 January 1939</ns2:date_of_death>
#     <ns2:place_of_death>Menton</ns2:place_of_death>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Sandymount</ns2:place_of_birth>
#     <ns2:nationality>Ireland</ns2:nationality>
#     <ns1:depiction>W. B. Yeats , Literature, 1923</ns1:depiction>
#     <ns2:date_of_birth>13 June 1865</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Selma_Lagerl%C3%B6f">
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Selma_Lagerl%C3%B6f</ns1:accountServiceHomepage>
#     <ns1:name>Selma Lagerlöf</ns1:name>
#     <ns1:depiction>Selma Lagerlöf , Literature, 1909</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>20 November 1858</ns2:date_of_birth>
#     <ns2:place_of_death>Mårbacka</ns2:place_of_death>
#     <ns1:gender>female</ns1:gender>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:nationality>Sweden</ns2:nationality>
#     <ns2:date_of_death>16 March 1940</ns2:date_of_death>
#     <ns2:year>1909</ns2:year>
#     <ns2:place_of_birth>Mårbacka</ns2:place_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/George_Wald">
#     <ns2:date_of_death>12 April 1997</ns2:date_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/George_Wald</ns1:accountServiceHomepage>
#     <ns2:place_of_birth>New York City</ns2:place_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death>Cambridge</ns2:place_of_death>
#     <ns2:year>1967</ns2:year>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:depiction>George Wald , Physiology or Medicine, 1967</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>George Wald</ns1:name>
#     <ns2:date_of_birth>18 November 1906</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Alexis_Carrel">
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>Paris</ns2:place_of_death>
#     <ns1:depiction>Alexis Carrel , Physiology or Medicine, 1912</ns1:depiction>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:homeland></ns2:homeland>
#     <ns1:name>Alexis Carrel</ns1:name>
#     <ns2:date_of_death>5 November 1944</ns2:date_of_death>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:date_of_birth>28 June 1873</ns2:date_of_birth>
#     <ns2:place_of_birth>Sainte-Foy-lès-Lyon</ns2:place_of_birth>
#     <ns2:year>1912</ns2:year>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Alexis_Carrel</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Ernesto_Teodoro_Moneta">
#     <ns1:name>Ernesto Teodoro Moneta</ns1:name>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:date_of_birth>20 September 1833</ns2:date_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death>10 February 1918</ns2:date_of_death>
#     <ns2:place_of_death>Milan</ns2:place_of_death>
#     <ns2:year>1907</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Ernesto_Teodoro_Moneta</ns1:accountServiceHomepage>
#     <ns1:depiction>Ernesto Teodoro Moneta , Peace, 1907</ns1:depiction>
#     <ns2:place_of_birth>Milan</ns2:place_of_birth>
#     <ns2:nationality>Italy</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Friends_Service_Council">
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:year>1947</ns2:year>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns1:name>Friends Service Council</ns1:name>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Friends_Service_Council</ns1:accountServiceHomepage>
#     <ns2:place_of_birth></ns2:place_of_birth>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:depiction>Friends Service Council , Peace, 1947</ns1:depiction>
#     <ns1:gender></ns1:gender>
#     <ns2:date_of_birth></ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Georg_Wittig">
#     <ns1:name>Georg Wittig</ns1:name>
#     <ns2:date_of_birth>16 June 1897</ns2:date_of_birth>
#     <ns1:depiction>Georg Wittig , Chemistry, 1979</ns1:depiction>
#     <ns2:nationality>Germany</ns2:nationality>
#     <ns1:gender>male</ns1:gender>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Georg_Wittig</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Berlin</ns2:place_of_birth>
#     <ns2:year>1979</ns2:year>
#     <ns2:place_of_death>Heidelberg</ns2:place_of_death>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#     <ns2:date_of_death>26 August 1987</ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Herbert_C._Brown">
#     <ns2:year>1979</ns2:year>
#     <ns1:name>Herbert C. Brown</ns1:name>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#     <ns2:date_of_birth>22 May 1912</ns2:date_of_birth>
#     <ns2:date_of_death>19 December 2004</ns2:date_of_death>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns1:depiction>Herbert C. Brown ,  born in the United Kingdom , Chemistry, 1979</ns1:depiction>
#     <ns2:place_of_birth>London</ns2:place_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>West Lafayette</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Herbert_C._Brown</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Arno_Penzias">
#     <ns1:depiction>Arno Penzias *, Physics, 1978</ns1:depiction>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:year>1978</ns2:year>
#     <ns1:name>Arno Penzias *</ns1:name>
#     <ns2:homeland>Germany</ns2:homeland>
#     <ns2:date_of_birth>26 April 1933</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:name>Arno Penzias</ns1:name>
#     <ns1:depiction>Arno Penzias ,  born in Germany , Physics, 1978</ns1:depiction>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Arno_Penzias</ns1:accountServiceHomepage>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns2:nationality></ns2:nationality>
#     <ns2:place_of_birth>Munich</ns2:place_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Michael_S._Brown">
#     <ns2:place_of_birth>Brooklyn</ns2:place_of_birth>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:year>1985</ns2:year>
#     <ns1:name>Michael S. Brown</ns1:name>
#     <ns2:date_of_birth>13 April 1941</ns2:date_of_birth>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Michael_S._Brown</ns1:accountServiceHomepage>
#     <ns1:depiction>Michael S. Brown , Physiology or Medicine, 1985</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Torsten_Wiesel">
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:nationality>Sweden</ns2:nationality>
#     <ns2:place_of_birth>Uppsala</ns2:place_of_birth>
#     <ns2:date_of_birth>3 June 1924</ns2:date_of_birth>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:name>Torsten Wiesel</ns1:name>
#     <ns1:depiction>Torsten Wiesel , Physiology or Medicine, 1981</ns1:depiction>
#     <ns2:year>1981</ns2:year>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Torsten_Wiesel</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/G%C3%BCnter_Blobel">
#     <ns1:depiction>Günter Blobel *, Physiology or Medicine, 1999</ns1:depiction>
#     <ns2:date_of_birth>21 May 1936</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/G%C3%BCnter_Blobel</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:name>Günter Blobel *</ns1:name>
#     <ns2:place_of_birth>Niegosławice, Lubusz Voivodeship</ns2:place_of_birth>
#     <ns1:name>Günter Blobel</ns1:name>
#     <ns1:gender>male</ns1:gender>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:date_of_death>18 February 2018</ns2:date_of_death>
#     <ns2:nationality></ns2:nationality>
#     <ns2:homeland>Germany</ns2:homeland>
#     <ns1:depiction>Günter Blobel ,  born in then Germany, now Poland , Physiology or Medicine, 1999</ns1:depiction>
#     <ns2:place_of_death>New York City</ns2:place_of_death>
#     <ns2:year>1999</ns2:year>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/W%C5%82adys%C5%82aw_Reymont">
#     <ns1:name>Władysław Reymont</ns1:name>
#     <ns2:nationality>Poland</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death>Warsaw</ns2:place_of_death>
#     <ns2:date_of_birth>7 May 1867</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/W%C5%82adys%C5%82aw_Reymont</ns1:accountServiceHomepage>
#     <ns2:nationality>Russia and Soviet Union</ns2:nationality>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Władysław Reymont , born in Congress Poland (Russian Empire), Literature, 1924</ns1:depiction>
#     <ns2:date_of_death>5 December 1925</ns2:date_of_death>
#     <ns2:year>1924</ns2:year>
#     <ns2:place_of_birth>Kobiele Wielkie</ns2:place_of_birth>
#     <ns1:depiction>Władysław Reymont ,  born in Congress Poland (Russian Empire) , Literature, 1924</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Allvar_Gullstrand">
#     <ns2:date_of_birth>5 June 1862</ns2:date_of_birth>
#     <ns1:depiction>Allvar Gullstrand , Physiology or Medicine, 1911</ns1:depiction>
#     <ns1:name>Allvar Gullstrand</ns1:name>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:year>1911</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_birth>Landskrona</ns2:place_of_birth>
#     <ns2:nationality>Sweden</ns2:nationality>
#     <ns2:date_of_death>28 July 1930</ns2:date_of_death>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death>Stockholm</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Allvar_Gullstrand</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Amartya_Sen">
#     <ns2:nationality>India</ns2:nationality>
#     <ns1:name>Amartya Sen</ns1:name>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:year>1998</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Amartya_Sen</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:place_of_birth>Manikganj District</ns2:place_of_birth>
#     <ns2:date_of_birth>3 November 1933</ns2:date_of_birth>
#     <ns1:depiction>Amartya Sen , Economics, 1998</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Robert_Robinson_(organic_chemist)">
#     <ns1:name>Robert Robinson</ns1:name>
#     <ns1:depiction>Robert Robinson , Chemistry, 1947</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death>8 February 1975</ns2:date_of_death>
#     <ns2:year>1947</ns2:year>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#     <ns2:date_of_birth>13 September 1886</ns2:date_of_birth>
#     <ns2:place_of_death>Great Missenden</ns2:place_of_death>
#     <ns2:place_of_birth>Chesterfield</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Robert_Robinson_(organic_chemist)</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Elizabeth_Blackburn">
#     <ns2:year>2009</ns2:year>
#     <ns2:date_of_birth>26 November 1948</ns2:date_of_birth>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:name>Elizabeth Blackburn *</ns1:name>
#     <ns1:depiction>Elizabeth Blackburn *, Physiology or Medicine, 2009</ns1:depiction>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:place_of_birth>Hobart</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Elizabeth_Blackburn</ns1:accountServiceHomepage>
#     <ns1:name>Elizabeth Blackburn</ns1:name>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>Elizabeth Blackburn ,  born in Australia , Physiology or Medicine, 2009</ns1:depiction>
#     <ns2:homeland>Australia</ns2:homeland>
#     <ns2:nationality></ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns1:gender>female</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Robert_W._Fogel">
#     <ns2:place_of_birth>New York City</ns2:place_of_birth>
#     <ns2:date_of_death>11 June 2013</ns2:date_of_death>
#     <ns2:date_of_birth>1 July 1926</ns2:date_of_birth>
#     <ns2:year>1993</ns2:year>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Robert_W._Fogel</ns1:accountServiceHomepage>
#     <ns1:depiction>Robert W. Fogel , Economics, 1993</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:name>Robert W. Fogel</ns1:name>
#     <ns2:place_of_death>Oak Lawn</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Robert_Coleman_Richardson">
#     <ns2:place_of_death>Ithaca</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Robert_Coleman_Richardson</ns1:accountServiceHomepage>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:depiction>Robert C. Richardson , Physics, 1996</ns1:depiction>
#     <ns1:name>Robert C. Richardson</ns1:name>
#     <ns2:year>1996</ns2:year>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns2:date_of_birth>26 June 1937</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death>19 February 2013</ns2:date_of_death>
#     <ns2:place_of_birth>Washington, D.C.</ns2:place_of_birth>
#     <ns1:gender>male</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/John_Galsworthy">
#     <ns2:date_of_death>31 January 1933</ns2:date_of_death>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/John_Galsworthy</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>John Galsworthy</ns1:name>
#     <ns2:place_of_death>London</ns2:place_of_death>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns2:year>1932</ns2:year>
#     <ns1:depiction>John Galsworthy , Literature, 1932</ns1:depiction>
#     <ns2:place_of_birth>Kingston upon Thames</ns2:place_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>14 August 1867</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Hans_Adolf_Krebs">
#     <ns2:place_of_birth>Hildesheim</ns2:place_of_birth>
#     <ns2:nationality></ns2:nationality>
#     <ns2:homeland>Germany</ns2:homeland>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Hans Adolf Krebs *, Physiology or Medicine, 1953</ns1:depiction>
#     <ns1:name>Hans Adolf Krebs</ns1:name>
#     <ns2:place_of_death>Oxford</ns2:place_of_death>
#     <ns2:date_of_birth>25 August 1900</ns2:date_of_birth>
#     <ns1:name>Hans Adolf Krebs *</ns1:name>
#     <ns2:year>1953</ns2:year>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Hans_Adolf_Krebs</ns1:accountServiceHomepage>
#     <ns1:depiction>Hans Adolf Krebs ,  born in Germany , Physiology or Medicine, 1953</ns1:depiction>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns2:date_of_death>22 November 1981</ns2:date_of_death>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Grazia_Deledda">
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Grazia_Deledda</ns1:accountServiceHomepage>
#     <ns2:nationality>Italy</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns1:depiction>Grazia Deledda , Literature, 1926</ns1:depiction>
#     <ns2:date_of_birth>27 September 1871</ns2:date_of_birth>
#     <ns2:year>1926</ns2:year>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns1:name>Grazia Deledda</ns1:name>
#     <ns2:place_of_birth>Nuoro</ns2:place_of_birth>
#     <ns2:place_of_death>Rome</ns2:place_of_death>
#     <ns2:date_of_death>15 August 1936</ns2:date_of_death>
#     <ns1:gender>female</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Albrecht_Kossel">
#     <ns2:place_of_birth>Rostock</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Albrecht_Kossel</ns1:accountServiceHomepage>
#     <ns2:year>1910</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>Germany</ns2:nationality>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:place_of_death>Heidelberg</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Albrecht Kossel , Physiology or Medicine, 1910</ns1:depiction>
#     <ns1:name>Albrecht Kossel</ns1:name>
#     <ns2:date_of_birth>16 September 1853</ns2:date_of_birth>
#     <ns2:date_of_death>5 July 1927</ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Auguste_Beernaert">
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death>6 October 1912</ns2:date_of_death>
#     <ns1:name>Auguste Beernaert</ns1:name>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Auguste_Beernaert</ns1:accountServiceHomepage>
#     <ns2:date_of_birth>26 July 1829</ns2:date_of_birth>
#     <ns1:depiction>Auguste Beernaert , Peace, 1909</ns1:depiction>
#     <ns2:place_of_birth>Ostend</ns2:place_of_birth>
#     <ns2:year>1909</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_death>Lucerne</ns2:place_of_death>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:nationality>Belgium</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Jimmy_Carter">
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:place_of_birth>Plains</ns2:place_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_birth>1 October 1924</ns2:date_of_birth>
#     <ns1:name>Jimmy Carter</ns1:name>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:year>2002</ns2:year>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Jimmy_Carter</ns1:accountServiceHomepage>
#     <ns1:depiction>Jimmy Carter , Peace, 2002</ns1:depiction>
#     <ns2:nationality>United States</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Joseph_Rotblat">
#     <ns1:name>Joseph Rotblat</ns1:name>
#     <ns2:date_of_death>31 August 2005</ns2:date_of_death>
#     <ns1:name>Joseph Rotblat *</ns1:name>
#     <ns2:place_of_birth>Warsaw</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Joseph_Rotblat</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death>London</ns2:place_of_death>
#     <ns2:year>1995</ns2:year>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns1:depiction>Joseph Rotblat *,  born in Congress Poland (Russian Empire) , Peace, 1995</ns1:depiction>
#     <ns2:date_of_birth>4 November 1908</ns2:date_of_birth>
#     <ns2:nationality></ns2:nationality>
#     <ns2:homeland>Poland</ns2:homeland>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Joseph Rotblat ,  born in then Russian Empire, now Poland , Peace, 1995</ns1:depiction>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Henrik_Dam">
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Copenhagen</ns2:place_of_birth>
#     <ns2:year>1943</ns2:year>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Henrik_Dam</ns1:accountServiceHomepage>
#     <ns2:place_of_death>Copenhagen</ns2:place_of_death>
#     <ns2:date_of_death>17 April 1976</ns2:date_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:nationality>Denmark</ns2:nationality>
#     <ns1:depiction>Henrik Dam , Physiology or Medicine, 1943</ns1:depiction>
#     <ns2:date_of_birth>21 February 1895</ns2:date_of_birth>
#     <ns1:name>Henrik Dam</ns1:name>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Arthur_L._Schawlow">
#     <ns2:date_of_death>28 April 1999</ns2:date_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_birth>Mount Vernon</ns2:place_of_birth>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns1:name>Arthur L. Schawlow</ns1:name>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns2:year>1981</ns2:year>
#     <ns2:date_of_birth>5 May 1921</ns2:date_of_birth>
#     <ns1:depiction>Arthur L. Schawlow , Physics, 1981</ns1:depiction>
#     <ns2:place_of_death>Palo Alto</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Arthur_L._Schawlow</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Mikhail_Sholokhov">
#     <ns2:year>1965</ns2:year>
#     <ns2:date_of_birth>11 May 1905</ns2:date_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns2:nationality>Russia and Soviet Union</ns2:nationality>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:place_of_birth>Kruzhilin</ns2:place_of_birth>
#     <ns1:depiction>Mikhail Sholokhov , Literature, 1965</ns1:depiction>
#     <ns1:name>Mikhail Sholokhov</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death>21 February 1984</ns2:date_of_death>
#     <ns2:place_of_death>Vyoshenskaya</ns2:place_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Mikhail_Sholokhov</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Barry_Marshall">
#     <ns2:date_of_birth>30 September 1951</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Barry_Marshall</ns1:accountServiceHomepage>
#     <ns2:place_of_death></ns2:place_of_death>
# ...
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Baruch S. Blumberg</ns1:name>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Linda_B._Buck">
#     <ns1:name>Linda B. Buck</ns1:name>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:depiction>Linda B. Buck , Physiology or Medicine, 2004</ns1:depiction>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:date_of_birth>29 January 1947</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Linda_B._Buck</ns1:accountServiceHomepage>
#     <ns2:place_of_birth>Seattle</ns2:place_of_birth>
#     <ns2:year>2004</ns2:year>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:gender>female</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/L%C3%A9on_Jouhaux">
#     <ns1:name>Léon Jouhaux</ns1:name>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:date_of_death>28 April 1954</ns2:date_of_death>
#     <ns1:depiction>Léon Jouhaux , Peace, 1951</ns1:depiction>
#     <ns2:date_of_birth>1 July 1879</ns2:date_of_birth>
#     <ns2:year>1951</ns2:year>
#     <ns2:place_of_death>Paris</ns2:place_of_death>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:place_of_birth>Pantin</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/L%C3%A9on_Jouhaux</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Luigi_Pirandello">
#     <ns2:date_of_birth>28 June 1867</ns2:date_of_birth>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Luigi_Pirandello</ns1:accountServiceHomepage>
#     <ns2:place_of_death>Rome</ns2:place_of_death>
#     <ns2:place_of_birth>Agrigento</ns2:place_of_birth>
#     <ns1:depiction>Luigi Pirandello , Literature, 1934</ns1:depiction>
#     <ns2:year>1934</ns2:year>
#     <ns1:name>Luigi Pirandello</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death>10 December 1936</ns2:date_of_death>
#     <ns2:nationality>Italy</ns2:nationality>
#     <ns1:gender>male</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Gabriela_Mistral">
#     <ns1:gender>female</ns1:gender>
#     <ns2:nationality>Chile</ns2:nationality>
#     <ns2:place_of_death>Hempstead</ns2:place_of_death>
#     <ns1:name>Gabriela Mistral</ns1:name>
#     <ns2:Course_education>Literature</ns2:Course_education>
#     <ns2:place_of_birth>Vicuña</ns2:place_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Gabriela_Mistral</ns1:accountServiceHomepage>
#     <ns1:depiction>Gabriela Mistral , Literature, 1945</ns1:depiction>
#     <ns2:date_of_death>10 January 1957</ns2:date_of_death>
#     <ns2:year>1945</ns2:year>
#     <ns2:date_of_birth>7 April 1889</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Barack_H._Obama">
#     <ns2:year>2009</ns2:year>
#     <ns2:place_of_birth>Kapiolani Medical Center for Women and Children</ns2:place_of_birth>
#     <ns2:date_of_birth>4 August 1961</ns2:date_of_birth>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:name>Barack H. Obama</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Barack_H._Obama</ns1:accountServiceHomepage>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns1:depiction>Barack H. Obama , Peace, 2009</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Charles_Richet">
#     <ns2:date_of_birth>26 August 1850</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Charles_Richet</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:depiction>Charles Richet , Physiology or Medicine, 1913</ns1:depiction>
#     <ns2:place_of_death>Paris</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Charles Richet</ns1:name>
#     <ns2:year>1913</ns2:year>
#     <ns2:place_of_birth>Paris</ns2:place_of_birth>
#     <ns2:date_of_death>4 December 1935</ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Leo_Esaki">
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns1:name>Leo Esaki</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Leo_Esaki</ns1:accountServiceHomepage>
#     <ns2:date_of_birth>12 March 1925</ns2:date_of_birth>
#     <ns2:nationality>Japan</ns2:nationality>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>Leo Esaki , Physics, 1973</ns1:depiction>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_birth>Ōsaka</ns2:place_of_birth>
#     <ns2:year>1973</ns2:year>
#     <ns2:date_of_death></ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Robert_B._Laughlin">
#     <ns2:nationality>United States</ns2:nationality>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Robert B. Laughlin</ns1:name>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:place_of_birth>Visalia</ns2:place_of_birth>
#     <ns1:depiction>Robert B. Laughlin , Physics, 1998</ns1:depiction>
#     <ns2:year>1998</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>1 November 1950</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Robert_B._Laughlin</ns1:accountServiceHomepage>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:Course_education>Physics</ns2:Course_education>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Eisaku_Sat%C5%8D">
#     <ns2:date_of_death>3 June 1975</ns2:date_of_death>
#     <ns1:depiction>Eisaku Satō , Peace, 1974</ns1:depiction>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Eisaku Satō</ns1:name>
#     <ns2:year>1974</ns2:year>
#     <ns2:date_of_birth>27 March 1901</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Eisaku_Sat%C5%8D</ns1:accountServiceHomepage>
#     <ns2:place_of_death>Tokyo</ns2:place_of_death>
#     <ns2:place_of_birth>Yamaguchi Prefecture</ns2:place_of_birth>
#     <ns2:nationality>Japan</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Ludwig_Quidde">
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Ludwig Quidde , Peace, 1927</ns1:depiction>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns2:year>1927</ns2:year>
#     <ns2:date_of_birth>23 March 1858</ns2:date_of_birth>
#     <ns2:place_of_death>Geneva</ns2:place_of_death>
#     <ns2:place_of_birth>Bremen</ns2:place_of_birth>
#     <ns2:date_of_death>4 March 1941</ns2:date_of_death>
#     <ns2:nationality>Germany</ns2:nationality>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Ludwig_Quidde</ns1:accountServiceHomepage>
#     <ns1:name>Ludwig Quidde</ns1:name>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Fran%C3%A7ois_Jacob">
#     <ns1:name>François Jacob</ns1:name>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Fran%C3%A7ois_Jacob</ns1:accountServiceHomepage>
#     <ns2:place_of_death>Paris</ns2:place_of_death>
#     <ns2:place_of_birth>Nancy</ns2:place_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:year>1965</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>François Jacob , Physiology or Medicine, 1965</ns1:depiction>
#     <ns2:date_of_death>19 April 2013</ns2:date_of_death>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:date_of_birth>17 June 1920</ns2:date_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/David_M._Lee">
#     <ns2:year>1996</ns2:year>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>David M. Lee , Physics, 1996</ns1:depiction>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_birth>20 January 1931</ns2:date_of_birth>
#     <ns1:name>David M. Lee</ns1:name>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/David_M._Lee</ns1:accountServiceHomepage>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:place_of_birth>Rye</ns2:place_of_birth>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Venkatraman_Ramakrishnan">
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:date_of_death></ns2:date_of_death>
#     <ns2:place_of_birth>Chidambaram</ns2:place_of_birth>
#     <ns1:depiction>Venkatraman Ramakrishnan *,  as a UK Citizen , Chemistry, 2009</ns1:depiction>
#     <ns2:homeland>India</ns2:homeland>
#     <ns1:name>Venkatraman Ramakrishnan</ns1:name>
#     <ns2:date_of_birth>5 April 1952</ns2:date_of_birth>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Venkatraman_Ramakrishnan</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>2009</ns2:year>
#     <ns1:depiction>Venkatraman Ramakrishnan ,  born in India , Chemistry, 2009</ns1:depiction>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns2:Course_education>Chemistry</ns2:Course_education>
#     <ns2:nationality></ns2:nationality>
#     <ns1:name>Venkatraman Ramakrishnan *</ns1:name>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/William_Lawrence_Bragg">
#     <ns2:place_of_birth>Adelaide</ns2:place_of_birth>
#     <ns1:gender>male</ns1:gender>
#     <ns2:date_of_birth>31 March 1890</ns2:date_of_birth>
#     <ns1:depiction>William Lawrence Bragg , Physics, 1915</ns1:depiction>
#     <ns2:date_of_death>1 July 1971</ns2:date_of_death>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns2:year>1915</ns2:year>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death>Ipswich</ns2:place_of_death>
#     <ns1:name>William Lawrence Bragg</ns1:name>
#     <ns1:depiction>William Lawrence Bragg ,  born in Australia , Physics, 1915</ns1:depiction>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/William_Lawrence_Bragg</ns1:accountServiceHomepage>
#     <ns2:nationality>Australia</ns2:nationality>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Hendrik_Lorentz">
#     <ns2:year>1902</ns2:year>
#     <ns2:place_of_birth>Arnhem</ns2:place_of_birth>
#     <ns2:date_of_death>4 February 1928</ns2:date_of_death>
#     <ns2:place_of_death>Haarlem</ns2:place_of_death>
#     <ns2:nationality>Netherlands</ns2:nationality>
#     <ns1:depiction>Hendrik Lorentz , Physics, 1902</ns1:depiction>
#     <ns2:Course_education>Physics</ns2:Course_education>
#     <ns2:date_of_birth>18 July 1853</ns2:date_of_birth>
#     <ns2:homeland></ns2:homeland>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Hendrik_Lorentz</ns1:accountServiceHomepage>
#     <ns1:gender>male</ns1:gender>
#     <ns1:name>Hendrik Lorentz</ns1:name>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Sune_Bergstr%C3%B6m">
#     <ns1:name>Sune Bergström</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns2:date_of_birth>10 January 1916</ns2:date_of_birth>
#     <ns1:depiction>Sune Bergström , Physiology or Medicine, 1982</ns1:depiction>
#     <ns2:year>1982</ns2:year>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_birth>Stockholm</ns2:place_of_birth>
#     <ns2:place_of_death>Stockholm</ns2:place_of_death>
#     <ns2:nationality>Sweden</ns2:nationality>
#     <ns2:date_of_death>15 August 2004</ns2:date_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Sune_Bergstr%C3%B6m</ns1:accountServiceHomepage>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Merton_H._Miller">
#     <ns1:name>Merton H. Miller</ns1:name>
#     <ns2:date_of_death>3 June 2000</ns2:date_of_death>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Merton_H._Miller</ns1:accountServiceHomepage>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:place_of_death>Chicago</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:place_of_birth>Boston</ns2:place_of_birth>
#     <ns2:date_of_birth>16 May 1923</ns2:date_of_birth>
#     <ns1:depiction>Merton H. Miller , Economics, 1990</ns1:depiction>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns2:year>1990</ns2:year>
#     <ns2:homeland></ns2:homeland>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Angus_Deaton">
#     <ns2:date_of_birth>19 October 1945</ns2:date_of_birth>
#     <ns2:nationality>United Kingdom</ns2:nationality>
#     <ns1:gender>male</ns1:gender>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_death></ns2:place_of_death>
#     <ns1:depiction>Angus Deaton ,  born in United Kingdom , Economics, 2015</ns1:depiction>
#     <ns2:year>2015</ns2:year>
#     <ns1:depiction>Angus Deaton , Economics, 2015</ns1:depiction>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Angus_Deaton</ns1:accountServiceHomepage>
#     <ns2:nationality>United States</ns2:nationality>
#     <ns2:Course_education>Economics</ns2:Course_education>
#     <ns2:place_of_birth>Edinburgh</ns2:place_of_birth>
#     <ns1:name>Angus Deaton</ns1:name>
#     <ns2:date_of_death></ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Hugo_Theorell">
#     <ns2:date_of_birth>6 July 1903</ns2:date_of_birth>
#     <ns2:date_of_death>15 August 1982</ns2:date_of_death>
#     <ns1:name>Hugo Theorell</ns1:name>
#     <ns2:homeland></ns2:homeland>
#     <ns2:place_of_birth>Linköping</ns2:place_of_birth>
#     <ns1:depiction>Hugo Theorell , Physiology or Medicine, 1955</ns1:depiction>
#     <ns2:nationality>Sweden</ns2:nationality>
#     <ns2:Course_education>Physiology or Medicine</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Hugo_Theorell</ns1:accountServiceHomepage>
#     <ns2:place_of_death>Stockholm</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns2:year>1955</ns2:year>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Louis_Renault_(jurist)">
#     <ns2:homeland></ns2:homeland>
#     <ns2:nationality>France</ns2:nationality>
#     <ns2:place_of_birth>Autun</ns2:place_of_birth>
#     <ns2:place_of_death>Barbizon</ns2:place_of_death>
#     <ns1:gender>male</ns1:gender>
#     <ns1:depiction>Louis Renault , Peace, 1907</ns1:depiction>
#     <ns2:date_of_birth>21 May 1843</ns2:date_of_birth>
#     <ns1:name>Louis Renault</ns1:name>
#     <ns2:year>1907</ns2:year>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Louis_Renault_(jurist)</ns1:accountServiceHomepage>
#     <ns2:date_of_death>8 February 1918</ns2:date_of_death>
#   </ns1:Person>
#   <ns1:Person rdf:about="http://en.wikipedia.org/wiki/Wangari_Maathai">
#     <ns1:name>Wangari Maathai</ns1:name>
#     <ns2:date_of_birth>1 April 1940</ns2:date_of_birth>
#     <ns2:nationality>Kenya</ns2:nationality>
#     <ns2:place_of_birth>Tetu</ns2:place_of_birth>
#     <ns2:place_of_death>Nairobi</ns2:place_of_death>
#     <ns2:Course_education>Peace</ns2:Course_education>
#     <ns1:gender>female</ns1:gender>
#     <ns2:year>2004</ns2:year>
#     <ns1:accountServiceHomepage>http://en.wikipedia.org/wiki/Wangari_Maathai</ns1:accountServiceHomepage>
#     <ns2:homeland></ns2:homeland>
#     <ns2:date_of_death>25 September 2011</ns2:date_of_death>
#     <ns1:depiction>Wangari Maathai , Peace, 2004</ns1:depiction>
#   </ns1:Person>
# </rdf:RDF>

# %% [markdown]
# ### Rdflib method
#
# OMG, we have failed to use SPARQLWrapper for querying. Sadly but hopefully, there is a another way!

# %%
def Rdflib_method(filepath, inputstring):
    graph = rdflib.Graph()
    graph.parse(filepath, format='xml')
    qres = graph.query(inputstring)
    for row in qres:
        print(row)
    return qres

# %% [markdown]
# How it works?

# %%
Rdflib_method("https://raw.githubusercontent.com/JinboCi/Sparql_tutorials/master/nwinner_list.xml", 
             """
             PREFIX  foaf: <http://xmlns.com/foaf/0.1/>
SELECT ?object 
WHERE {
  # ?subject ?predicate "Tibet".
  # ?subject foaf:name ?object
}
""")
# Out:
# (rdflib.term.Literal('14th Dalai Lama'),)
